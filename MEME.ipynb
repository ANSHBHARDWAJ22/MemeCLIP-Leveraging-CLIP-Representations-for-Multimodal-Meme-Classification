# %%
import torch
print("CUDA Available:", torch.cuda.is_available())
print("Device:", torch.cuda.get_device_name(0) if torch.cuda.is_available() else "CPU")
# Out:
# CUDA Available: True
# Device: Tesla T4

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cp "/content/drive/MyDrive/memeCLIP_PROJECT.zip" .
# !unzip memeCLIP_PROJECT.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: memeCLIP_PROJECT/venv/Lib/site-packages/transformers/models/grounding_dino/modeling_grounding_dino.py
#   inflating: memeCLIP_PROJECT/venv/Lib/site-packages/transformers/models/grounding_dino/modular_grounding_dino.py
#   inflating: memeCLIP_PROJECT/venv/Lib/site-packages/transformers/models/grounding_dino/processing_grounding_dino.py
#   inflating: memeCLIP_PROJECT/venv/Lib/site-packages/transformers/models/grounding_dino/__init__.py
#    creating: memeCLIP_PROJECT/venv/Lib/site-packages/transformers/models/grounding_dino/__pycache__/
#   inflating: memeCLIP_PROJECT/venv/Lib/site-packages/transformers/models/grounding_dino/__pycache__/configuration_grounding_dino.cpython-312.pyc
#   inflating: memeCLIP_PROJECT/venv/Lib/site-packages/transformers/models/grounding_dino/__pycache__/image_processing_grounding_dino.cpython-312.pyc
# ...

# %%
# %cd memeCLIP_PROJECT
# Out:
# [Errno 2] No such file or directory: 'memeCLIP_PROJECT'
# /content

# %%
# Install PyTorch Lightning
# !pip install pytorch-lightning

# Install Hugging Face Transformers
# !pip install transformers

# Install tqdm (progress bar)
# !pip install tqdm

# Install TorchMetrics
# !pip install torchmetrics

# Install OpenAI CLIP (and dependencies)
# !pip install git+https://github.com/openai/CLIP.git

# If you're using a local "models" module, upload it manually or from a GitHub repo
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.1/823.1 kB 18.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 109.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 90.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 56.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 76.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 962.5/962.5 kB 57.9 MB/s eta 0:00:00
# ...

# %%
# !pip install yacs

# %%
# Out:
# python3: can't open file '/content/main.py': [Errno 2] No such file or directory

# %%
# !ls /content/
# !ls /content/memeCLIP_PROJECT/
# Out:
# drive  memeCLIP_PROJECT  memeCLIP_PROJECT.zip  sample_data
# 2409.14703v2.pdf  datasets.py  lightning_logs  MemeCLIP.py  PrideMM.csv  venv
# configs.py	  Images       main.py	       models.py    __pycache__

# %%
# !ls /content/drive/MyDrive/
# Out:
# 'Colab Notebooks'   memeCLIP_PROJECT.zip   model.ckpt

# %%
# %cd /content/memeCLIP_PROJECT
# !python main.py
# Out:
# /content/memeCLIP_PROJECT
# 2025-05-31 11:21:07.933576: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1748690468.196100    7534 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1748690468.268424    7534 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-05-31 11:21:08.834949: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# ...

# %%
ls

# %%
pwd
# Out:
# '/content/memeCLIP_PROJECT'

# %%
pwd
# Out:
# '/content/memeCLIP_PROJECT'
